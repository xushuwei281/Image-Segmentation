# %%
from WrappedScript import processImage
import matplotlib.pyplot as plt

# %%
for i in range(10):
    a,b,c=processImage(file_path="testingImage.jpg",minArea=(i/5)*0.00025)
    print(b)
# Out:
# 108
# 103
# 73
# 57
# 55
# 54
# 53
# 53
# 52
# 50
#   File "<ipython-input-6-739cc5c99f05>", line 4
#     return
#           ^
# SyntaxError: 'return' outside function
